# %% [markdown]
# <img src="https://raw.githubusercontent.com/kafonek/calc2/master/discussion2.PNG"/>

# %%
def f(r):
    import math
    a = 1
    b = .001
    return a * math.exp(-b * r) / r**3

# %%
f(.5)
# Out:
# 7.996000999833354

# %%
f(5)
# Out:
# 0.007960099833541458

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np
X = np.arange(.1, 5, .001)
Y = [f(x) for x in X]

plt.xlabel("Force (Verruckts)")
plt.ylabel("Attractive Force (Fermis)")
plt.plot(X, Y)
# Out:
# <img src="data:image/png;base64,...">

# %%
### We'll integrate under the graph from .5 - 5
from scipy.integrate import quad
quad(f, .5, 5)
# Out:
# (1.9782011505430617, 1.3326156815671442e-09)

# %%
f(0)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-6-421db934c3f8> in <module>()
# ----> 1 f(0)
#
# <ipython-input-1-860ee32ed950> in f(r)
#       3     a = 1
#       4     b = .001
# ----> 5     return a * math.exp(-b * r) / r**3
#
# ZeroDivisionError: float division by zero
